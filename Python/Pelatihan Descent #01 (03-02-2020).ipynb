# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Pelatihan Descent #01 (03-02-2020) Python Class

# %% [markdown]
# Selamat datang teman-teman peserta pelatihan! Semoga pelatihan kali ini bermanfaat untuk kita semua!

# %%
print("Selamat datang di Pelatihan Descent!")
print("Hai kamu, apa kabar hari ini?")

# %% [markdown]
# Jawab dong...

# %%
print("Hai juga nama saya {nama}, kabar saya {kabar}")

# %% [markdown]
# # Importing Packages

# %%
import pandas as pd

# %% [markdown]
# Sekarang giliran kamu buat coba import packages lainnya. coba import numpy, matplotlib, seaborn & scipy.
# Pastiin packages nya udah terinstall dulu ya.

# %% [markdown]
# # Identifier

# %% [markdown]
# Kenapa ya, kok error gini? Tolong bantu benerin dong..

# %%
0_nama = 'Descent'
ruang kelas = 323
pelatihan% = 'python'

# %% [markdown]
# # Indentation

# %% [markdown]
# Mau semangatin yang lagi belajar python tapi ga bisa, kenapa ya?

# %%
def menulis():
    text = "\n Semangat belajar Python !"
 print(*5)

menulis()

# %% [markdown]
# # Data types

# %% [markdown]
# Ini contoh variable dengan tipe data string

# %%
string = 'Python'
print(type(string))

# %% [markdown]
# Mau tau dong tipe data yang ada di bawah ini apa aja?

# %%
my_string = 'Pelatihan Descent'
number = 3
bener_ga = 4<5
bahasa = ['R', 'Python']

# %% [markdown]
# ## Casting

# %% [markdown]
# Kita bisa loh ngubah tipe data yang satu ke tipe data yang lain gini contohnya

# %%
string = '3'
float_num = 3.20

print(int(string), type(int(string)))
print(int(float_num), type(int(float_num)))

# %% [markdown]
# Duh mau ngitung uang kok hasil nya gini yah? Bisa bantu ga?

# %%
uang_python = '2000'
uang_r = '1000'

uang_python_cast = #dicasting dong
uang_r_cast = #dicasting dong

print('Sebelum Casting')
print(uang_python + uang_r)
print('Sesudah Casting')
print(uang_python_cast + uang_r_cast)

# %% [markdown]
# # String

# %% [markdown]
# Aku adalah string, banyak yang bilang aku array of char

# %%
my_string = "ini adalah string"
print(my_string)

# %% [markdown]
# Aku bisa diakses dengan index loh. Oh iya indexnya mulai dari nol yaaa

# %%
my_string[0]

# %% [markdown]
# Coba kamu tau ga diurutan ke lima ada huruf apa?

# %%
huruf_ke_5 = my_string[]
print(huruf_ke_5)

# %% [markdown]
# Kalau index nya -2 huruf apa ya yang keluar?

# %%
my_string[-2]

# %% [markdown]
# ## Concate

# %% [markdown]
# String bisa digabung pake tanda + loh

# %%
print("Pelatihan" + " Python")

# %% [markdown]
# Tolong persatukan dua bagian yang terpisah ini

# %%
bagian_1 = "Aku Suka"
bagian_2 = "Belajar Python"

bersatu = 
print(bersatu)

# %% [markdown]
# ## Size of String

# %% [markdown]
# Kalian bisa mengukur berapa panjang string pke len()

# %% [markdown]
# Berapa panjang ku?

# %%
string_panjang = 'shfjknf  krkgmkhpt rlrmfiwnw rkro3495 4wmsdkmfglp'
panjang_nya = #berapa ya?

print(panjang_nya)

# %% [markdown]
# ## Slicing

# %%
my_string = "ini adalah string"
my_string[0:5]

# %% [markdown]
# Coba karakter apa aja yang ada diurutan ke 5 sampai 10?

# %%
my_string = "ini adalah string"

# %% [markdown]
# # List

# %%
colors = ["red", "orange", "yellow", "green", "indigo", "white"]
colors

# %% [markdown]
# Kita bisa akses element dalam list dengan index. Ingat ya index nya mulai dari 0

# %%
colors[0]

# %% [markdown]
# Coba kita akses warna diurutan ke 5, hayoo index nya berapa?

# %%
colors[]

# %% [markdown]
# Kita juga bisa tau loh suatu element dari list itu ada di index ke berapa

# %%
colors.index('red')

# %% [markdown]
# Warna indigo ada di index ke berapa ya?

# %%
colors

# %% [markdown]
# ## Remove

# %%
colors.remove("white")
colors"

# %% [markdown]
# ## Append

# %%
colors.append("violet")
colors

# %% [markdown]
# ## Insert

# %%
colors.insert(4, "blue") 
colors

# %% [markdown]
# ## Slicing List

# %%
colors[3:6]

# %% [markdown]
# ## Lists are Mutable

# %% [markdown]
# Coba ubah angka di urutan ke 3 jadi 323

# %%
list_number = [2, 14, 26, 41, 63] 
#ubah

list_number

# %% [markdown]
# ## How long is a list

# %% [markdown]
# Tadi ada berapa warna ya di dalam list kita?

# %%
len(colors)

# %%
gabungan  = list_number + colors
gabungan

# %% [markdown]
# # Dictionary

# %% [markdown]
# Aku mirip seperti list tapi aku bukan diakses dengan index tapi dengan unique key

# %%
menu = {"spam":12.50, "carbona":20, "salad":15}

# %% [markdown]
# Salad Harganya berapa ya?

# %%
menu["salad"]

# %% [markdown]
# Mau nambahin menu baru ah

# %%
menu["cake"] = 6 
menu

# %% [markdown]
# Spam ini menu apa sih? Hapus aja

# %%
del menu["spam"]
menu

# %% [markdown]
# Restorannya Bangkrut ga ada menu makanan lagi

# %%
dict.clear(menu)
menu

# %% [markdown]
# # Tuples

# %%
tutor = ('Kharis', 'Ari', 'Nashir', 'Ayu', 'Novia')

# %% [markdown]
# Siapa ya tutor urutan ke 4 dalam tuple?

# %%
tutor[]

# %% [markdown]
# ## Tuples immutable

# %%
z = (5,4,3) 
z[2] = 0

# %% [markdown]
# ## Tuples & Assigment

# %%
(a, b) = (99, 98)
print(a)

# %% [markdown]
# ## Tuples are Comparable

# %%
(11, 10, 20) < (5, 1, 2)

# %%
(10, 100, 1) < (5, 1, 2)

# %% [markdown]
# # Condition

# %%
a = 200
b = 33
if b > a:
    print("b is greater than a")
elif a == b:
    print("a and b are equal")
else:
    print("a is greater than b")

# %% [markdown]
# Aku mau jajan nih tapi sisa uang cuma 5000 di kantin cuma ada soto, batagor, dan roti

# %% [markdown]
# Kalau uang nya cukup aku mau jajan salah satu diantara ketiganya, kalau ga cukup aku ga jadi jajan & kelaparan :(

# %%
uang_jajan = 5000
jajanan = {'soto':12000, 'batagor':8000, 'roti':5100}

if uang_jajan  jajanan['soto']:
    print("Jajan Soto")
elif uang_jajan >= ['batagor']:
    print("Jajan Batagor")
elif uang_jajan >= jajanan['']:
    print("Jajan Roti")
else: print("Ga jajan, Kelaparan :(")

# %% [markdown]
# # Loop

# %% [markdown]
# ## While

# %%
i = 1
while i < 6:
  print(i)
  i += 1

# %% [markdown]
# Coba buat program yang

# %%
i = 1
while i  25:
    print('Saya akan semangat belajar', i)

# %% [markdown]
# ## For

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    print(x)

# %%
pizzas = ["New York Style Pizza", "Pan Pizza", "Thin n Crispy Pizza", "Stuffed Crust Pizza"]
humans = ['Aldo','Fikron','Ammar','Dian']

for (, ) in zip(, ):
    print(human+' Eat '+pizza)

# %% [markdown]
# # Function

# %%
def menulis_100kali(kalimat):
    print(('\n'+kalimat)*100)

menulis_100kali('Semangat Belajar')

# %% [markdown]
# Kamu kok gendutan sih?

# %% [markdown]
# Belakangan ini banyak yang bilang begitu ke kamu, tapi kamu ga percaya. Jadi kamu coba buktiin kalau kamu gak kelebihan berat badan.

# %% [markdown]
# Untuk itu kamu membuat program untuk menghitung indeks massa tubuh dengan rumus berat(kg)/(tinggi(m)^2).
# Kalau Hasilnya <= 18.4 artinya berat badan kamu kurang, kalau 18.5 sampai 24.9 artinya berat kamu ideal, kalau 25 sampa 29.9 artinya berat badan kamu berlebih, kalau 30 sampai 39.9 artinya kamu gemuk, dan kalau sampa 40 ke atas kamu sangat gemuk.

# %%
def hitung_imt(berat, tinggi):
    imt = #hitung di sini
    print('IMT : ',imt)
    if imt <= 18.4:
        print("Berat Badan Kurang")
    elif (imt  18.5)  (imt <= ):
        print("Berat Badan Ideal")
    elif (imt ) and (imt <=29.9):
        print("Berat Badan Berlebih")
    elif (imt >= 30)  (imt ):
        print("Gemuk")
    else: print('Sangat Gemuk')

berat_mu =  #kg
tinggi_mu =  #m

hitung_imt(berat_mu, tinggi_mu)

# %% [markdown]
# # Read Data

# %%
import pandas as pd
data1 = pd.read_excel('path')

# %%
import pandas as pd
data2 = pd.read_csv('tvfix.csv', sep=";")
data2.head()

# %% [markdown]
# ## Data Info

# %%
data1.info()

# %%
data2

# %% [markdown]
# ## Describe Data

# %%
data1.describe()

# %%
data2
